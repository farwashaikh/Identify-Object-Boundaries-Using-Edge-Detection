# %%
import cv2
import matplotlib.pyplot as plt
image = cv2.imread('farwa.jpg', cv2.IMREAD_GRAYSCALE)
edges = cv2.Canny(image, threshold1=100, threshold2=200)
plt.imshow(edges, cmap='gray')
plt.title('Edge Detection')
plt.show()
